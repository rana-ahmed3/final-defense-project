# %% [markdown]
# # project problem

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Load the airline safety dataset

df=pd.read_csv("airline-safety.csv")

# %%
df.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 1                      1                88
# 2                      0                 0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   airline                 56 non-null     object
#  1   avail_seat_km_per_week  56 non-null     int64
#  2   incidents_85_99         56 non-null     int64
#  3   fatal_accidents_85_99   56 non-null     int64
#  4   fatalities_85_99        56 non-null     int64
#  5   incidents_00_14         56 non-null     int64
#  6   fatal_accidents_00_14   56 non-null     int64
#  7   fatalities_00_14        56 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.describe()
# Out:
#        avail_seat_km_per_week  incidents_85_99  fatal_accidents_85_99  \
# count            5.600000e+01        56.000000              56.000000
# mean             1.384621e+09         7.178571               2.178571
# std              1.465317e+09        11.035656               2.861069
# min              2.593733e+08         0.000000               0.000000
# 25%              4.740362e+08         2.000000               0.000000
# 50%              8.029089e+08         4.000000               1.000000
# 75%              1.847239e+09         8.000000               3.000000
# max              7.139291e+09        76.000000              14.000000
#
#        fatalities_85_99  incidents_00_14  fatal_accidents_00_14  \
# count         56.000000        56.000000              56.000000
# mean         112.410714         4.125000               0.660714
# std          146.691114         4.544977               0.858684
# min            0.000000         0.000000               0.000000
# ...

# %%
#using matplotlib drawing the histogram
df.hist(bins=50, figsize=(15,20))
# Out:
# array([[<AxesSubplot:title={'center':'avail_seat_km_per_week'}>,
#         <AxesSubplot:title={'center':'incidents_85_99'}>,
#         <AxesSubplot:title={'center':'fatal_accidents_85_99'}>],
#        [<AxesSubplot:title={'center':'fatalities_85_99'}>,
#         <AxesSubplot:title={'center':'incidents_00_14'}>,
#         <AxesSubplot:title={'center':'fatal_accidents_00_14'}>],
#        [<AxesSubplot:title={'center':'fatalities_00_14'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.tail()
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 51       United / Continental*              7139291291               19
# 52  US Airways / America West*              2455687887               16
# 53            Vietnam Airlines               625084918                7
# 54             Virgin Atlantic              1005248585                1
# 55             Xiamen Airlines               430462962                9
#
#     fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 51                      8               319               14
# 52                      7               224               11
# 53                      3               171                1
# 54                      0                 0                0
# 55                      1                82                2
#
#     fatal_accidents_00_14  fatalities_00_14
# 51                      2               109
# 52                      2                23
# ...

# %%
df.shape
# Out:
# (56, 8)

# %%
df["total_incidents(85-14)"]=df["incidents_85_99"]+df["incidents_00_14"]
df.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14  total_incidents(85-14)
# 0                      0                 0                       2
# 1                      1                88                      82
# ...

# %%
df["total_fatal_accidents(85-14)"]=df["fatal_accidents_85_99"]+df["fatal_accidents_00_14"]
df.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14  total_incidents(85-14)  \
# 0                      0                 0                       2
# 1                      1                88                      82
# ...

# %%
df["total_fatalities(85-14)"]=df["fatalities_85_99"]+df["fatalities_00_14"]
df.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14  total_incidents(85-14)  \
# 0                      0                 0                       2
# 1                      1                88                      82
# ...

# %%
# Drop the colum

drop_cols = [ 'airline','incidents_85_99','fatal_accidents_85_99','fatalities_85_99',
'incidents_00_14','fatal_accidents_00_14','fatalities_00_14']
df = df.drop(drop_cols, axis=1)

# %%
df.head()
# Out:
#    avail_seat_km_per_week  total_incidents(85-14)  \
# 0               320906734                       2
# 1              1197672318                      82
# 2               385803648                       7
# 3               596871813                       8
# 4              1865253802                       4
#
#    total_fatal_accidents(85-14)  total_fatalities(85-14)
# 0                             0                        0
# 1                            15                      216
# 2                             0                        0
# 3                             1                       64
# 4                             0                        0

# %%
corr_matrix=df.corr()
corr_matrix['total_fatalities(85-14)'].sort_values(ascending=False)
# Out:
# total_fatalities(85-14)         1.000000
# total_fatal_accidents(85-14)    0.601338
# total_incidents(85-14)          0.396446
# avail_seat_km_per_week          0.298597
# Name: total_fatalities(85-14), dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributess=["total_fatalities(85-14)","total_fatal_accidents(85-14)","total_incidents(85-14)","avail_seat_km_per_week"]
scatter_matrix(df[attributess], figsize=(12,8))
# Out:
# array([[<AxesSubplot:xlabel='total_fatalities(85-14)', ylabel='total_fatalities(85-14)'>,
#         <AxesSubplot:xlabel='total_fatal_accidents(85-14)', ylabel='total_fatalities(85-14)'>,
#         <AxesSubplot:xlabel='total_incidents(85-14)', ylabel='total_fatalities(85-14)'>,
#         <AxesSubplot:xlabel='avail_seat_km_per_week', ylabel='total_fatalities(85-14)'>],
#        [<AxesSubplot:xlabel='total_fatalities(85-14)', ylabel='total_fatal_accidents(85-14)'>,
#         <AxesSubplot:xlabel='total_fatal_accidents(85-14)', ylabel='total_fatal_accidents(85-14)'>,
#         <AxesSubplot:xlabel='total_incidents(85-14)', ylabel='total_fatal_accidents(85-14)'>,
#         <AxesSubplot:xlabel='avail_seat_km_per_week', ylabel='total_fatal_accidents(85-14)'>],
#        [<AxesSubplot:xlabel='total_fatalities(85-14)', ylabel='total_incidents(85-14)'>,
#         <AxesSubplot:xlabel='total_fatal_accidents(85-14)', ylabel='total_incidents(85-14)'>,
# ...

# %%
df.plot(kind="scatter",x="total_fatal_accidents(85-14)",y="total_fatalities(85-14)")
# Out:
# <AxesSubplot:xlabel='total_fatal_accidents(85-14)', ylabel='total_fatalities(85-14)'>

# %% [markdown]
# # Data prepare for machine learning algorithm

# %%
# cleaning the data
df.isnull()
# Out:
#     avail_seat_km_per_week  total_incidents(85-14)  \
# 0                    False                   False
# 1                    False                   False
# 2                    False                   False
# 3                    False                   False
# 4                    False                   False
# 5                    False                   False
# 6                    False                   False
# 7                    False                   False
# 8                    False                   False
# 9                    False                   False
# 10                   False                   False
# 11                   False                   False
# 12                   False                   False
# 13                   False                   False
# 14                   False                   False
# 15                   False                   False
# 16                   False                   False
# ...

# %%
df.isnull().sum()
# Out:
# avail_seat_km_per_week          0
# total_incidents(85-14)          0
# total_fatal_accidents(85-14)    0
# total_fatalities(85-14)         0
# dtype: int64

# %%
drop_cols = ['avail_seat_km_per_week','total_incidents(85-14)']
df = df.drop(drop_cols, axis=1)

# %%
#spilt dataset
X = df.drop("total_fatalities(85-14)", axis="columns")
y = df.drop("total_fatal_accidents(85-14)", axis="columns")
print("shape of X = ", X.shape)
print("shape of y = ", y.shape)
# Out:
# shape of X =  (56, 1)
# shape of y =  (56, 1)

# %%
# selection trainor test data for model
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.1, random_state=51)
print("shape of X_train = ",X_train.shape)
print("shape of y_train = ",y_train.shape)
print("shape of X_test = ",X_test.shape)
print("shape of y_test = ",y_test.shape)
# Out:
# shape of X_train =  (50, 1)
# shape of y_train =  (50, 1)
# shape of X_test =  (6, 1)
# shape of y_test =  (6, 1)

# %% [markdown]
# # Select a model and train it

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

#model = LinearRegression()

model = DecisionTreeRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
model.predict([[1]])
# Out:
# array([101.3125])

# %%
#model.coef_
#model.intercept_
#model.predict([[3]])[0][0].round(2)

# %%
y_pre = model.predict(X_test)
y_pre
# Out:
# array([  0.        , 276.16666667, 101.3125    , 175.4       ,
#          0.        ,   0.        ])

# %% [markdown]
# # Find tune in model

# %%
model.score(X_test,y_test)
# Out:
# 0.4882674919221952

# %% [markdown]
# # Save ML model use joblib

# %%
import joblib
joblib.dump(model, "Airline_fatalities_predictor.pkl")
# Out:
# ['Airline_fatalities_predictor.pkl']

# %%
model_a = joblib.load("Airline_fatalities_predictor.pkl")

# %%
model_a.predict([[2]])
# Out:
# array([175.4])
